# %% [markdown]
# # Customer Churn Analysis

# %% [markdown]
# Data Description

# %% [raw]
# The task is to predict whether the customer is retention or attrition which decides the business. The data set contains 7043 rows with 21 columns(including the target variable). Apply various machine learning models to predict customer churn. The target column have two variables, so we will use classification model.

# %% [markdown]
# Importing Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the Data Set.

# %%
df=pd.read_csv('customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape    #checking data dimensions.
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Checking Null Values in the data.

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Statistical summary.

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [raw]
# We can see that the standard deviation is high in tenure and monthly charges columns.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# We know that customerID is unique id, So we will remove this column.

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df.SeniorCitizen.value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# Analysis.

# %% [markdown]
# Categorical data

# %%
categorical=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',     'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling','PaymentMethod']

# %%
for k in categorical:
    sns.countplot(x=k,hue='Churn',data=df)
    plt.xticks(rotation=90)
    plt.show()

# %% [raw]
# Observations:
# We can see that the highest 'attrition' happens with the people:
#     Senior Citizen "0"
#     people who don't have a partner
#     people with no dependents
#     with people who have phone service
#     With people who have fiber optic service
#     With people no online security
#     With people no online backup
#     With people no tech Support
#     With people who don't stream TV
#     People with no contract (because they will have an option to cancel service anytime without penalty because they don't have any contract with company)
#     People with paperless billing
#    People who provide Electronic checks.

# %%
df.TotalCharges.value_counts()
# Out:
# 20.2       11
#            11
# 19.75       9
# 19.9        8
# 19.65       8
#            ..
# 329.8       1
# 2933.95     1
# 3219.75     1
# 4520.15     1
# 1096.25     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %% [raw]
# We can see that in the column Total charges we can see that there are 11 empty rows. That's the reason being numerical column it is not displayed when we check descriptive statistics, So first we will fill these values with null and will replace them with mean in the upcoming process.

# %%
pd.set_option('display.max_rows',None)

# %%
import numpy as np

# %%
df['TotalCharges'].eq(' ')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['TotalCharges']=df['TotalCharges'].fillna(df['TotalCharges'].mean())

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
for i in df.describe().columns:
    sns.distplot(df[i].dropna())
    plt.show()

# %%
df.skew()
# Out:
# SeniorCitizen     1.833633
# tenure            0.239540
# MonthlyCharges   -0.220524
# TotalCharges      0.962394
# dtype: float64

# %% [raw]
# Taking thresold value as +/- 0.5 we can see that there is skewness in Total charges and SeniorCitizen. SeniorCitizen column is mentioned with binary values we will remove skewness only in TotalCharges

# %%
from sklearn.preprocessing import power_transform

# %%
df['TotalCharges']=power_transform(df['TotalCharges'].values.reshape(-1,1))

# %%
df['TotalCharges'].skew()
# Out:
# -0.14489927430068528

# %%
for i in df.describe().columns:
    sns.boxplot(df[i].dropna())
    plt.show()

# %% [markdown]
# Encoding

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# Dealing with categorical variables.

# %% [raw]
# We need numerical data to train the model. So we will do an encoding process to change the categorical data into numeric data.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])
df['Partner']=le.fit_transform(df['Partner'])
df['Dependents']=le.fit_transform(df['Dependents'])
df['PhoneService']=le.fit_transform(df['PhoneService'])
df['MultipleLines']=le.fit_transform(df['MultipleLines'])
df['InternetService']=le.fit_transform(df['InternetService'])
df['OnlineSecurity']=le.fit_transform(df['OnlineSecurity'])
df['OnlineBackup']=le.fit_transform(df['OnlineBackup'])
df['DeviceProtection']=le.fit_transform(df['DeviceProtection'])
df['TechSupport']=le.fit_transform(df['TechSupport'])
df['StreamingTV']=le.fit_transform(df['StreamingTV'])
df['StreamingMovies']=le.fit_transform(df['StreamingMovies'])
df['Contract']=le.fit_transform(df['Contract'])
df['PaperlessBilling']=le.fit_transform(df['PaperlessBilling'])
df['PaymentMethod']=le.fit_transform(df['PaymentMethod'])
df['Churn']=le.fit_transform(df['Churn'])

# %%
x=df.drop('Churn',axis=1)
y=df['Churn']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lr=LogisticRegression()
dr=DecisionTreeClassifier()
rf=RandomForestClassifier()
sv=SVC()

# %%
model=[lr,dr,rf,sv]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=40)

# %%
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print('accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# accuracy score of LogisticRegression() is:
# 0.7856128726928537
# [[1374  179]
#  [ 274  286]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      1553
#            1       0.62      0.51      0.56       560
#
#     accuracy                           0.79      2113
#    macro avg       0.72      0.70      0.71      2113
# weighted avg       0.78      0.79      0.78      2113
#
#
#
# accuracy score of DecisionTreeClassifier() is:
# 0.7169900615238997
# [[1241  312]
#  [ 286  274]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81      1553
#            1       0.47      0.49      0.48       560
#
#     accuracy                           0.72      2113
#    macro avg       0.64      0.64      0.64      2113
# weighted avg       0.72      0.72      0.72      2113
#
#
#
# accuracy score of RandomForestClassifier() is:
# 0.7737813535257927
# [[1361  192]
#  [ 286  274]]
# ...

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
Lrs=cross_val_score(lr,x,y,cv=5)
print('cross validation of LogisticRegression:',Lrs.mean())
# Out:
# cross validation of LogisticRegression: 0.8020735208723142

# %%
drs=cross_val_score(dr,x,y,cv=5)
print('cross validation of DecisionTreeClassiffier:',drs.mean())
# Out:
# cross validation of DecisionTreeClassiffier: 0.7278153026001678

# %%
svr=cross_val_score(sv,x,y,cv=5)
print('cross validation of SVM:',svr.mean())
# Out:
# cross validation of SVM: 0.7892946722369185

# %%
rfr=cross_val_score(rf,x,y,cv=5)
print('cross valdation of RandomForestClassifier:',rfr.mean())
# Out:
# cross valdation of RandomForestClassifier: 0.7898631564939673

# %% [raw]
# We see that random forest classifier is performing good. We will do hyperparameter tunning.

# %% [markdown]
# Hyper Parameter Tuning.

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param={'criterion':['gini','entropy']}
gd=GridSearchCV(estimator=rf,param_grid=grid_param,scoring='accuracy',cv=5)
gd.fit(x,y)
best_parameter=gd.best_params_
print('best_parameter:',best_parameter)
# Out:
# best_parameter: {'criterion': 'gini'}

# %%
gd_pred=gd.best_estimator_.predict(x_test)

# %%
accuracy_score(y_test,gd_pred)
# Out:
# 0.9971604353999054

# %%
print(confusion_matrix(y_test,gd_pred))
print(classification_report(y_test,gd_pred))
# Out:
# [[1549    4]
#  [   2  558]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1553
#            1       0.99      1.00      0.99       560
#
#     accuracy                           1.00      2113
#    macro avg       1.00      1.00      1.00      2113
# weighted avg       1.00      1.00      1.00      2113

# %% [raw]
# With hyper parameter tunning we got 99%% accuracy and good F1 score . S0, we will save this model.

# %% [markdown]
# Saving the Model

# %%
import joblib
joblib.dump(gd.best_estimator_,'customer_churn.obj')
# Out:
# ['customer_churn.obj']
